# %% [markdown]
# # ARIMA Inference
#
# This notebook loads the registered ARIMA pipeline from W&B Model Registry and predicts directly on raw `test.csv`. The preprocessing/allocation logic is inside the pipeline object.

# %%
# %pip install -q "numpy>=1.24,<3" "pandas>=2.0,<3" "statsmodels>=0.14,<1" "wandb>=0.19,<1" "cloudpickle>=3.0,<4"

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
from pathlib import Path
import json

import cloudpickle
import numpy as np
import pandas as pd
import wandb

WANDB_PROJECT = "Walmart-Recruiting---Store-Sales-Forecasting"
REGISTRY_ARTIFACT_URI = "wandb-registry-model/Walmart_ARIMA_Pipeline:champion"
RUN_NAME = "ARIMA_Registry_Inference_Submission"
OUTPUT_DIR = Path("outputs")
OUTPUT_DIR.mkdir(exist_ok=True)

DATA_DIR_CANDIDATES = [
    Path("/content/drive/MyDrive/walmart_competition_data"),
    Path("/content/Walmart-Recruiting---Store-Sales-Forecasting/data"),
    Path("../../../../data"),
    Path("../../../data"),
    Path("data"),
]


def resolve_data_dir(candidates):
    required = ["test.csv"]
    for candidate in candidates:
        if all((candidate / name).exists() for name in required):
            return candidate
    raise FileNotFoundError("Could not find test.csv. Update DATA_DIR_CANDIDATES.")


def find_pipeline_file(artifact_dir):
    candidates = sorted(Path(artifact_dir).rglob("*.pkl"))
    if not candidates:
        raise FileNotFoundError(f"No .pkl pipeline file found in {artifact_dir}")
    preferred = [path for path in candidates if "pipeline" in path.name.lower()]
    return preferred[0] if preferred else candidates[0]


DATA_DIR = resolve_data_dir(DATA_DIR_CANDIDATES)
print(f"Using data directory: {DATA_DIR.resolve()}")
# Out:
# Using data directory: /content/drive/MyDrive/walmart_competition_data

# %%
test_raw = pd.read_csv(DATA_DIR / "test.csv", parse_dates=["Date"])
test_raw = test_raw.sort_values(["Date", "Store", "Dept"]).reset_index(drop=True)

print({"test_rows": len(test_raw), "test_columns": list(test_raw.columns)})
display(test_raw.head())
# Out:
# {'test_rows': 115064, 'test_columns': ['Store', 'Dept', 'Date', 'IsHoliday']}
#    Store  Dept       Date  IsHoliday
# 0      1     1 2012-11-02      False
# 1      1     2 2012-11-02      False
# 2      1     3 2012-11-02      False
# 3      1     4 2012-11-02      False
# 4      1     5 2012-11-02      False

# %% [markdown]
# ## Download Registered ARIMA Pipeline

# %%
run = wandb.init(project=WANDB_PROJECT, name=RUN_NAME, job_type="inference", reinit=True)
model_artifact = run.use_artifact(REGISTRY_ARTIFACT_URI, type="model")
artifact_dir = model_artifact.download()
pipeline_path = find_pipeline_file(artifact_dir)

with pipeline_path.open("rb") as file:
    pipeline = cloudpickle.load(file)

print(f"Loaded pipeline: {pipeline_path}")
print(getattr(pipeline, "metadata", {}))
# Out:
# Finishing previous runs because reinit is set to True.
#  View run <strong style="color:#cdcd00">ARIMA_Registry_Inference_Submission</strong> at: <a href='https://wandb.ai/kende23-n-a/Walmart-Recruiting---Store-Sales-Forecasting/runs/35ybdctr' target="_blank">https://wandb.ai/kende23-n-a/Walmart-Recruiting---Store-Sales-Forecasting/runs/35ybdctr</a><br> View project at: <a href='https://wandb.ai/kende23-n-a/Walmart-Recruiting---Store-Sales-Forecasting' target="_blank">https://wandb.ai/kende23-n-a/Walmart-Recruiting---Store-Sales-Forecasting</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260710_151019-35ybdctr/logs</code>
# Tracking run with wandb version 0.28.0
# Run data is saved locally in <code>/content/wandb/run-20260710_151031-wdn3ps1r</code>
# Syncing run <strong><a href='https://wandb.ai/kende23-n-a/Walmart-Recruiting---Store-Sales-Forecasting/runs/wdn3ps1r' target="_blank">ARIMA_Registry_Inference_Submission</a></strong> to <a href='https://wandb.ai/kende23-n-a/Walmart-Recruiting---Store-Sales-Forecasting' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/kende23-n-a/Walmart-Recruiting---Store-Sales-Forecasting' target="_blank">https://wandb.ai/kende23-n-a/Walmart-Recruiting---Store-Sales-Forecasting</a>
#  View run at <a href='https://wandb.ai/kende23-n-a/Walmart-Recruiting---Store-Sales-Forecasting/runs/wdn3ps1r' target="_blank">https://wandb.ai/kende23-n-a/Walmart-Recruiting---Store-Sales-Forecasting/runs/wdn3ps1r</a>
# wandb:   1 of 1 files downloaded.
# Loaded pipeline: /content/artifacts/walmart-arima-best-pipeline:v0/arima_best_pipeline.pkl
# {'model_family': 'ARIMA', 'uses_exog': False, 'seasonal_order': 'disabled', 'validation_weeks': 39, 'refit_scope': 'full_train'}

# %%
predictions = np.asarray(pipeline.predict(test_raw), dtype=float)
predictions = np.clip(predictions, 0, None)

if len(predictions) != len(test_raw):
    raise ValueError(f"Prediction row mismatch: {len(predictions)} != {len(test_raw)}")
if not np.isfinite(predictions).all():
    raise ValueError("Predictions contain non-finite values.")

prediction_summary = {
    "prediction_min": float(predictions.min()),
    "prediction_mean": float(predictions.mean()),
    "prediction_max": float(predictions.max()),
    "prediction_std": float(predictions.std()),
    "submission_rows": int(len(predictions)),
}
prediction_summary
# Out:
# {'prediction_min': 0.0,
#  'prediction_mean': 15969.287847084655,
#  'prediction_max': 460527.6420758332,
#  'prediction_std': 22528.841423511065,
#  'submission_rows': 115064}

# %%
submission = pd.DataFrame({
    "Id": test_raw["Store"].astype(str) + "_" + test_raw["Dept"].astype(str) + "_" + test_raw["Date"].dt.strftime("%Y-%m-%d"),
    "Weekly_Sales": predictions,
})

submission_path = OUTPUT_DIR / "arima_registry_submission.csv"
submission.to_csv(submission_path, index=False)
print(f"Saved {submission_path} with {len(submission)} rows")
display(submission.head())
# Out:
# Saved outputs/arima_registry_submission.csv with 115064 rows
#                Id  Weekly_Sales
# 0  1_1_2012-11-02  38609.577022
# 1  1_2_2012-11-02  45799.431069
# 2  1_3_2012-11-02   8895.115867
# 3  1_4_2012-11-02  38095.357781
# 4  1_5_2012-11-02  30933.372361

# %%
run.log({f"inference/{key}": value for key, value in prediction_summary.items()})
run.summary.update(prediction_summary)
run.summary["registry_artifact"] = REGISTRY_ARTIFACT_URI
run.summary["pipeline_file"] = str(pipeline_path)

submission_artifact = wandb.Artifact(
    name="arima-registry-submission",
    type="submission",
    metadata={**prediction_summary, "registry_artifact": REGISTRY_ARTIFACT_URI},
)
submission_artifact.add_file(str(submission_path))
run.log_artifact(submission_artifact)
run.finish()

print("ARIMA inference complete: registry pipeline -> raw test -> submission artifact.")
# Out:
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>inference/prediction_max</td><td>▁</td></tr><tr><td>inference/prediction_mean</td><td>▁</td></tr><tr><td>inference/prediction_min</td><td>▁</td></tr><tr><td>inference/prediction_std</td><td>▁</td></tr><tr><td>inference/submission_rows</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>inference/prediction_max</td><td>460527.64208</td></tr><tr><td>inference/prediction_mean</td><td>15969.28785</td></tr><tr><td>inference/prediction_min</td><td>0</td></tr><tr><td>inference/prediction_std</td><td>22528.84142</td></tr><tr><td>inference/submission_rows</td><td>115064</td></tr><tr><td>pipeline_file</td><td>/content/artifacts/w...</td></tr><tr><td>prediction_max</td><td>460527.64208</td></tr><tr><td>prediction_mean</td><td>15969.28785</td></tr><tr><td>prediction_min</td><td>0</td></tr><tr><td>prediction_std</td><td>22528.84142</td></tr><tr><td>+2</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">ARIMA_Registry_Inference_Submission</strong> at: <a href='https://wandb.ai/kende23-n-a/Walmart-Recruiting---Store-Sales-Forecasting/runs/wdn3ps1r' target="_blank">https://wandb.ai/kende23-n-a/Walmart-Recruiting---Store-Sales-Forecasting/runs/wdn3ps1r</a><br> View project at: <a href='https://wandb.ai/kende23-n-a/Walmart-Recruiting---Store-Sales-Forecasting' target="_blank">https://wandb.ai/kende23-n-a/Walmart-Recruiting---Store-Sales-Forecasting</a><br>Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260710_151031-wdn3ps1r/logs</code>
# ARIMA inference complete: registry pipeline -> raw test -> submission artifact.
