# %%
# %pip install -q "numpy>=1.24,<3" "pandas>=2.0,<3" "scikit-learn>=1.3,<2" "statsmodels>=0.14,<1" "wandb>=0.19,<1" "cloudpickle>=3.0,<4"

from pathlib import Path
import itertools
import warnings
import cloudpickle

import numpy as np
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_squared_error
from statsmodels.tsa.statespace.sarimax import SARIMAX

try:
    import wandb
except Exception:
    wandb = None

warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", 100)

# %%
try:
    from google.colab import drive

    if not Path("/content/drive/MyDrive").exists():
        drive.mount("/content/drive")
except Exception:
    pass
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Configuration
#
# The search remains constrained for only 104 training weeks: `p,q=0..4`, `d∈{0,1}`. Annual seasonality enters through Fourier exogenous variables rather than a SARIMA seasonal order.

# %%
DATA_DIR_CANDIDATES = [
    Path("/content/drive/MyDrive/walmart_competition_data"),
    Path("/content/Walmart-Recruiting---Store-Sales-Forecasting/data"),
    Path("../../../../data"),
    Path("../../../data"),
    Path("data"),
]

VALIDATION_WEEKS = 39
HOLIDAY_WEIGHT = 5.0
ORDER_GRID = list(itertools.product(range(5), [0, 1], range(5)))
USE_EXOG_OPTIONS = [True]
ALLOCATION_STRATEGIES = ["last_year_share"]
SELECTED_EXOG_FEATURES = [
    "week_sin",
    "week_cos",
    "week_sin_2",
    "week_cos_2",
    "holiday_share",
    "log_total_markdown",
]
USE_LOG_TARGET = True

RUN_WANDB = True
WANDB_PROJECT = "Walmart-Recruiting---Store-Sales-Forecasting"
WANDB_RUN_NAME = "ARIMAX_Repaired_LogTarget_Fourier_Experiment"
WANDB_MODE = "online"

RUN_TEST_SUBMISSION = False
OUTPUT_DIR = Path("outputs")
OUTPUT_DIR.mkdir(exist_ok=True)


def resolve_data_dir(candidates):
    required = ["train.csv", "test.csv", "features.csv", "stores.csv"]
    for candidate in candidates:
        if all((candidate / name).exists() for name in required):
            return candidate
    raise FileNotFoundError("Could not find Walmart data directory.")


def weighted_mae(y_true, y_pred, is_holiday, holiday_weight=5.0):
    weights = np.where(np.asarray(is_holiday).astype(bool), holiday_weight, 1.0)
    return float(
        np.sum(weights * np.abs(np.asarray(y_true) - np.asarray(y_pred)))
        / np.sum(weights)
    )


def rmse(y_true, y_pred):
    return float(np.sqrt(mean_squared_error(y_true, y_pred)))


DATA_DIR = resolve_data_dir(DATA_DIR_CANDIDATES)
print(f"Using data directory: {DATA_DIR.resolve()}")
# Out:
# Using data directory: /content/drive/MyDrive/walmart_competition_data

# %%
train = pd.read_csv(DATA_DIR / "train.csv", parse_dates=["Date"])
test = pd.read_csv(DATA_DIR / "test.csv", parse_dates=["Date"])
features = pd.read_csv(DATA_DIR / "features.csv", parse_dates=["Date"])
stores = pd.read_csv(DATA_DIR / "stores.csv")

train = train.sort_values(["Date", "Store", "Dept"]).reset_index(drop=True)
test = test.sort_values(["Date", "Store", "Dept"]).reset_index(drop=True)
features = features.sort_values(["Date", "Store"]).reset_index(drop=True)

print(
    {
        "train": train.shape,
        "test": test.shape,
        "features": features.shape,
        "stores": stores.shape,
    }
)
display(train.head())
# Out:
# {'train': (421570, 5), 'test': (115064, 4), 'features': (8190, 12), 'stores': (45, 3)}
#    Store  Dept       Date  Weekly_Sales  IsHoliday
# 0      1     1 2010-02-05      24924.50      False
# 1      1     2 2010-02-05      50605.27      False
# 2      1     3 2010-02-05      13740.12      False
# 3      1     4 2010-02-05      39954.04      False
# 4      1     5 2010-02-05      32229.38      False

# %%
all_dates = np.array(sorted(train["Date"].unique()))
validation_dates = all_dates[-VALIDATION_WEEKS:]
validation_start = validation_dates[0]

train_part = train[train["Date"] < validation_start].copy()
val_part = train[train["Date"] >= validation_start].copy()

print(
    {
        "train_rows": len(train_part),
        "validation_rows": len(val_part),
        "train_end": train_part["Date"].max().date(),
        "validation_start": pd.Timestamp(validation_start).date(),
        "validation_end": val_part["Date"].max().date(),
    }
)
# Out:
# {'train_rows': 305982, 'validation_rows': 115588, 'train_end': datetime.date(2012, 1, 27), 'validation_start': datetime.date(2012, 2, 3), 'validation_end': datetime.date(2012, 10, 26)}

# %% [markdown]
# ## ARIMAX Feature Engineering and Feature Selection
#
# This repaired ARIMAX experiment uses a compact set of future-known aggregate covariates. Raw markdown totals are transformed with `log1p`, annual seasonality is represented with two Fourier harmonics, and every exogenous column is standardized using training-only statistics. The aggregate sales target is fitted on `log1p` scale. This avoids the unstable raw-scale, correlation-selected eight-feature specification used in the previous run.
#
# Selected inputs: first and second annual Fourier harmonics, holiday share, and log total markdown. Order search covers `p,q=0..4` and `d∈{0,1}`; only the stronger last-year-share allocation is retained.

# %%
def weekly_total_sales(frame):
    return (
        frame.groupby("Date", as_index=True)["Weekly_Sales"]
        .sum()
        .sort_index()
        .asfreq("W-FRI")
    )


def build_weekly_exog(features_frame):
    frame = features_frame.copy()
    markdown_cols = [c for c in frame.columns if c.startswith("MarkDown")]
    for col in markdown_cols:
        frame[col] = frame[col].fillna(0.0)

    numeric_cols = ["Temperature", "Fuel_Price", "CPI", "Unemployment"] + markdown_cols
    for col in numeric_cols:
        if col in frame.columns:
            frame[col] = frame[col].fillna(frame[col].median())

    aggregations = {
        "IsHoliday": "mean",
        "Temperature": "mean",
        "Fuel_Price": "mean",
        "CPI": "mean",
        "Unemployment": "mean",
    }
    for col in markdown_cols:
        aggregations[col] = "sum"

    weekly = frame.groupby("Date").agg(aggregations).sort_index().asfreq("W-FRI")
    weekly = weekly.rename(columns={"IsHoliday": "holiday_share"})
    weekly["total_markdown"] = (
        weekly[markdown_cols].sum(axis=1) if markdown_cols else 0.0
    )
    weekly["weekofyear"] = weekly.index.isocalendar().week.astype(int)
    weekly["week_sin"] = np.sin(2 * np.pi * weekly["weekofyear"] / 52.0)
    weekly["week_cos"] = np.cos(2 * np.pi * weekly["weekofyear"] / 52.0)
    weekly["week_sin_2"] = np.sin(4 * np.pi * weekly["weekofyear"] / 52.0)
    weekly["week_cos_2"] = np.cos(4 * np.pi * weekly["weekofyear"] / 52.0)
    weekly["log_total_markdown"] = np.log1p(weekly["total_markdown"].clip(lower=0.0))
    weekly = weekly.replace([np.inf, -np.inf], np.nan).ffill().bfill().fillna(0.0)
    return weekly


def select_exog_features(
    exog_train,
    y_train,
    corr_threshold=0.05,
    max_features=6,
):
    candidates = []
    y = pd.Series(y_train, index=exog_train.index).astype(float)
    for col in exog_train.columns:
        values = exog_train[col].astype(float)
        if values.nunique(dropna=False) <= 1:
            continue
        corr = values.corr(y)
        if pd.isna(corr):
            continue
        candidates.append((col, abs(float(corr))))

    ranked = sorted(candidates, key=lambda item: item[1], reverse=True)
    selected = [col for col, corr in ranked if corr >= corr_threshold]
    if not selected:
        selected = [col for col, _ in ranked[:max_features]]

    pruned = []
    corr_matrix = exog_train[selected].corr().abs() if selected else pd.DataFrame()
    for col in selected:
        if len(pruned) >= max_features:
            break
        if all(corr_matrix.loc[col, prev] < 0.95 for prev in pruned):
            pruned.append(col)
    return pruned


weekly_sales_train = weekly_total_sales(train_part)
weekly_exog = build_weekly_exog(features)
exog_train_all = weekly_exog.loc[weekly_sales_train.index]
selected_exog_features = SELECTED_EXOG_FEATURES.copy()

print("Selected ARIMAX exogenous features:")
for feature in selected_exog_features:
    print("-", feature)
# Out:
# Selected ARIMAX exogenous features:
# - week_sin
# - week_cos
# - week_sin_2
# - week_cos_2
# - holiday_share
# - log_total_markdown

# %% [markdown]
# ## Allocation Strategies
#
# The aggregate ARIMA/ARIMAX model forecasts total weekly sales. Kaggle needs row-level Store-Dept predictions, so we compare two allocation strategies:
#
# - `last_year_share`: uses same Store-Dept sales 52 weeks ago;
# - `blended_share`: combines last-year sales with recent pre-validation average sales.

# %%
def fit_forecast_arima(
    y_train, forecast_dates, order, exog_train=None, exog_future=None
):
    model_target = np.log1p(np.clip(np.asarray(y_train, dtype=float), 0.0, None))
    model = SARIMAX(
        model_target,
        order=order,
        seasonal_order=(0, 0, 0, 0),
        exog=exog_train,
        enforce_stationarity=False,
        enforce_invertibility=False,
    )
    result = model.fit(disp=False, maxiter=300)
    forecast = result.get_forecast(
        steps=len(forecast_dates), exog=exog_future
    ).predicted_mean
    forecast = np.expm1(np.asarray(forecast))
    forecast = pd.Series(forecast, index=forecast_dates).clip(lower=0.0)
    return result, forecast


def make_row_forecast(
    target_frame,
    history_frame,
    aggregate_forecast,
    strategy="last_year_share",
    recent_weeks=13,
):
    target = target_frame[["Store", "Dept", "Date", "IsHoliday"]].copy()
    history = history_frame[["Store", "Dept", "Date", "Weekly_Sales"]].copy()

    last_year = history.copy()
    last_year["Date"] = last_year["Date"] + pd.Timedelta(days=364)
    last_year = last_year.rename(columns={"Weekly_Sales": "last_year_sales"})

    series_mean = (
        history.groupby(["Store", "Dept"], as_index=False)["Weekly_Sales"]
        .mean()
        .rename(columns={"Weekly_Sales": "series_mean_sales"})
    )
    recent_cutoff = history["Date"].max() - pd.Timedelta(days=7 * recent_weeks)
    recent_mean = (
        history[history["Date"] > recent_cutoff]
        .groupby(["Store", "Dept"], as_index=False)["Weekly_Sales"]
        .mean()
        .rename(columns={"Weekly_Sales": "recent_mean_sales"})
    )

    target = target.merge(last_year, on=["Store", "Dept", "Date"], how="left")
    target = target.merge(series_mean, on=["Store", "Dept"], how="left")
    target = target.merge(recent_mean, on=["Store", "Dept"], how="left")

    if strategy == "last_year_share":
        base = target["last_year_sales"].fillna(target["series_mean_sales"])
    elif strategy == "blended_share":
        last_year_base = target["last_year_sales"].fillna(target["series_mean_sales"])
        recent_base = target["recent_mean_sales"].fillna(target["series_mean_sales"])
        base = 0.70 * last_year_base + 0.30 * recent_base
    else:
        raise ValueError(f"Unknown allocation strategy: {strategy}")

    target["allocation_base"] = base.fillna(0.0).clip(lower=0.0)
    date_base_sum = target.groupby("Date")["allocation_base"].transform("sum")
    row_count = target.groupby("Date")["allocation_base"].transform("size")
    target["share"] = np.where(
        date_base_sum > 0, target["allocation_base"] / date_base_sum, 1.0 / row_count
    )
    target["aggregate_forecast"] = target["Date"].map(aggregate_forecast)
    target["prediction"] = (
        (target["aggregate_forecast"] * target["share"]).fillna(0.0).clip(lower=0.0)
    )
    return target["prediction"].to_numpy()


def make_seasonal_naive_forecast(target_frame, history_frame):
    target = target_frame[["Store", "Dept", "Date"]].copy()
    history = history_frame[["Store", "Dept", "Date", "Weekly_Sales"]].copy()
    history["Date"] = history["Date"] + pd.Timedelta(days=364)
    history = history.rename(columns={"Weekly_Sales": "last_year_sales"})
    fallback = (
        history_frame.groupby(["Store", "Dept"], as_index=False)["Weekly_Sales"]
        .median()
        .rename(columns={"Weekly_Sales": "series_median_sales"})
    )
    target = target.merge(history, on=["Store", "Dept", "Date"], how="left")
    target = target.merge(fallback, on=["Store", "Dept"], how="left")
    return (
        target["last_year_sales"]
        .fillna(target["series_median_sales"])
        .fillna(0.0)
        .clip(lower=0.0)
        .to_numpy()
    )

# %%
weekly_sales = weekly_total_sales(train_part)
forecast_dates = list(pd.to_datetime(validation_dates))
exog_train_raw = weekly_exog.loc[weekly_sales.index, selected_exog_features].astype(float)
exog_val_raw = weekly_exog.loc[forecast_dates, selected_exog_features].astype(float)
exog_center = exog_train_raw.mean(axis=0)
exog_scale = exog_train_raw.std(axis=0).replace(0.0, 1.0)
exog_train_selected = (exog_train_raw - exog_center) / exog_scale
exog_val_selected = (exog_val_raw - exog_center) / exog_scale
assert np.isfinite(exog_train_selected.to_numpy()).all()
assert np.isfinite(exog_val_selected.to_numpy()).all()

seasonal_naive_pred = make_seasonal_naive_forecast(val_part, train_part)
seasonal_naive_wmae = weighted_mae(
    val_part["Weekly_Sales"], seasonal_naive_pred, val_part["IsHoliday"], HOLIDAY_WEIGHT
)
print(f"Seasonal naive WMAE: {seasonal_naive_wmae:.4f}")

wandb_run = None
trial_table = None
if RUN_WANDB:
    if wandb is None:
        raise ImportError(
            "wandb is not available. Re-run the install/import cell or install wandb."
        )
    wandb_run = wandb.init(
        project=WANDB_PROJECT,
        name=WANDB_RUN_NAME,
        job_type="arima-experiment",
        mode=WANDB_MODE,
        reinit=True,
        config={
            "validation_weeks": VALIDATION_WEEKS,
            "holiday_weight": HOLIDAY_WEIGHT,
            "order_grid_size": len(ORDER_GRID),
            "use_exog_options": USE_EXOG_OPTIONS,
            "allocation_strategies": ALLOCATION_STRATEGIES,
            "selected_exog_features": selected_exog_features,
            "target_transform": "log1p",
            "exog_scaling": "training mean/std",
            "seasonal_order": "disabled",
        },
    )
    trial_table = wandb.Table(
        columns=[
            "trial",
            "order",
            "use_exog",
            "allocation",
            "wmae",
            "mae",
            "rmse",
            "improvement_vs_seasonal_naive_pct",
        ]
    )

results = []
trial = 0
for order in ORDER_GRID:
    for use_exog in USE_EXOG_OPTIONS:
        exog_train = (
            exog_train_selected if use_exog and selected_exog_features else None
        )
        exog_val = exog_val_selected if use_exog and selected_exog_features else None
        try:
            _, aggregate_forecast = fit_forecast_arima(
                weekly_sales, forecast_dates, order, exog_train, exog_val
            )
        except Exception as exc:
            print(
                f"Trial {trial:03d} failed for order={order}, use_exog={use_exog}: {exc}"
            )
            trial += 1
            continue

        for allocation in ALLOCATION_STRATEGIES:
            pred = make_row_forecast(
                val_part, train_part, aggregate_forecast, allocation
            )
            wmae_value = weighted_mae(
                val_part["Weekly_Sales"], pred, val_part["IsHoliday"], HOLIDAY_WEIGHT
            )
            mae_value = float(mean_absolute_error(val_part["Weekly_Sales"], pred))
            rmse_value = rmse(val_part["Weekly_Sales"], pred)
            improvement = (
                100.0 * (seasonal_naive_wmae - wmae_value) / seasonal_naive_wmae
            )
            row = {
                "trial": trial,
                "order": order,
                "use_exog": use_exog,
                "allocation": allocation,
                "validation/wmae": wmae_value,
                "validation/mae": mae_value,
                "validation/rmse": rmse_value,
                "improvement_vs_seasonal_naive_pct": improvement,
            }
            results.append(row)
            print(
                f"Trial {trial:03d} | order={order} exog={use_exog} allocation={allocation} | WMAE={wmae_value:.4f} | improvement={improvement:.2f}%"
            )
            if RUN_WANDB:
                wandb.log(
                    {
                        "trial": trial,
                        "validation/wmae": wmae_value,
                        "validation/mae": mae_value,
                        "validation/rmse": rmse_value,
                        "improvement_vs_seasonal_naive_pct": improvement,
                        "baseline/seasonal_naive_wmae": seasonal_naive_wmae,
                    },
                    step=trial,
                )
                trial_table.add_data(
                    trial,
                    str(order),
                    use_exog,
                    allocation,
                    wmae_value,
                    mae_value,
                    rmse_value,
                    improvement,
                )
        trial += 1

results_df = pd.DataFrame(results).sort_values("validation/wmae").reset_index(drop=True)
best_result = results_df.iloc[0].to_dict()

if RUN_WANDB:
    wandb.log({"arima_experiment/trials": trial_table})
    wandb.summary["best_validation_wmae"] = float(best_result["validation/wmae"])
    wandb.summary["best_validation_mae"] = float(best_result["validation/mae"])
    wandb.summary["best_validation_rmse"] = float(best_result["validation/rmse"])
    wandb.summary["best_order"] = str(best_result["order"])
    wandb.summary["best_use_exog"] = bool(best_result["use_exog"])
    wandb.summary["best_allocation"] = best_result["allocation"]
    wandb.summary["seasonal_naive_wmae"] = float(seasonal_naive_wmae)
    wandb.finish()

display(results_df.head(10))
best_result
# Out:
# Seasonal naive WMAE: 1800.1736
# Tracking run with wandb version 0.28.0
# Run data is saved locally in <code>/content/wandb/run-20260717_114510-0bgqftvh</code>
# Syncing run <strong><a href='https://wandb.ai/kende23-n-a/Walmart-Recruiting---Store-Sales-Forecasting/runs/0bgqftvh' target="_blank">ARIMAX_Repaired_LogTarget_Fourier_Experiment</a></strong> to <a href='https://wandb.ai/kende23-n-a/Walmart-Recruiting---Store-Sales-Forecasting' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/kende23-n-a/Walmart-Recruiting---Store-Sales-Forecasting' target="_blank">https://wandb.ai/kende23-n-a/Walmart-Recruiting---Store-Sales-Forecasting</a>
#  View run at <a href='https://wandb.ai/kende23-n-a/Walmart-Recruiting---Store-Sales-Forecasting/runs/0bgqftvh' target="_blank">https://wandb.ai/kende23-n-a/Walmart-Recruiting---Store-Sales-Forecasting/runs/0bgqftvh</a>
# Trial 000 | order=(0, 0, 0) exog=True allocation=last_year_share | WMAE=15952.3233 | improvement=-786.15%
# Trial 001 | order=(0, 0, 1) exog=True allocation=last_year_share | WMAE=15952.2889 | improvement=-786.15%
# Trial 002 | order=(0, 0, 2) exog=True allocation=last_year_share | WMAE=15951.8164 | improvement=-786.13%
# Trial 003 | order=(0, 0, 3) exog=True allocation=last_year_share | WMAE=15915.4702 | improvement=-784.11%
# Trial 004 | order=(0, 0, 4) exog=True allocation=last_year_share | WMAE=15929.1974 | improvement=-784.87%
# Trial 005 | order=(0, 1, 0) exog=True allocation=last_year_share | WMAE=3695.8199 | improvement=-105.30%
# Trial 006 | order=(0, 1, 1) exog=True allocation=last_year_share | WMAE=1830.1113 | improvement=-1.66%
# Trial 007 | order=(0, 1, 2) exog=True allocation=last_year_share | WMAE=1854.0596 | improvement=-2.99%
# Trial 008 | order=(0, 1, 3) exog=True allocation=last_year_share | WMAE=1902.4908 | improvement=-5.68%
# Trial 009 | order=(0, 1, 4) exog=True allocation=last_year_share | WMAE=1960.7045 | improvement=-8.92%
# Trial 010 | order=(1, 0, 0) exog=True allocation=last_year_share | WMAE=4208.9964 | improvement=-133.81%
# Trial 011 | order=(1, 0, 1) exog=True allocation=last_year_share | WMAE=1824.4816 | improvement=-1.35%
# Trial 012 | order=(1, 0, 2) exog=True allocation=last_year_share | WMAE=1835.2707 | improvement=-1.95%
# Trial 013 | order=(1, 0, 3) exog=True allocation=last_year_share | WMAE=2287.2427 | improvement=-27.06%
# Trial 014 | order=(1, 0, 4) exog=True allocation=last_year_share | WMAE=2129.7850 | improvement=-18.31%
# Trial 015 | order=(1, 1, 0) exog=True allocation=last_year_share | WMAE=3543.7731 | improvement=-96.86%
# Trial 016 | order=(1, 1, 1) exog=True allocation=last_year_share | WMAE=1876.1873 | improvement=-4.22%
# Trial 017 | order=(1, 1, 2) exog=True allocation=last_year_share | WMAE=1832.4395 | improvement=-1.79%
# Trial 018 | order=(1, 1, 3) exog=True allocation=last_year_share | WMAE=1925.9041 | improvement=-6.98%
# Trial 019 | order=(1, 1, 4) exog=True allocation=last_year_share | WMAE=1868.0885 | improvement=-3.77%
# Trial 020 | order=(2, 0, 0) exog=True allocation=last_year_share | WMAE=3859.4077 | improvement=-114.39%
# Trial 021 | order=(2, 0, 1) exog=True allocation=last_year_share | WMAE=1926.7086 | improvement=-7.03%
# Trial 022 | order=(2, 0, 2) exog=True allocation=last_year_share | WMAE=3478.3896 | improvement=-93.23%
# Trial 023 | order=(2, 0, 3) exog=True allocation=last_year_share | WMAE=2055.3510 | improvement=-14.18%
# Trial 024 | order=(2, 0, 4) exog=True allocation=last_year_share | WMAE=2046.7295 | improvement=-13.70%
# Trial 025 | order=(2, 1, 0) exog=True allocation=last_year_share | WMAE=3456.7824 | improvement=-92.02%
# Trial 026 | order=(2, 1, 1) exog=True allocation=last_year_share | WMAE=1870.3414 | improvement=-3.90%
# Trial 027 | order=(2, 1, 2) exog=True allocation=last_year_share | WMAE=1943.0403 | improvement=-7.94%
# Trial 028 | order=(2, 1, 3) exog=True allocation=last_year_share | WMAE=1864.3769 | improvement=-3.57%
# Trial 029 | order=(2, 1, 4) exog=True allocation=last_year_share | WMAE=1867.3321 | improvement=-3.73%
# Trial 030 | order=(3, 0, 0) exog=True allocation=last_year_share | WMAE=3831.7135 | improvement=-112.85%
# Trial 031 | order=(3, 0, 1) exog=True allocation=last_year_share | WMAE=2297.3082 | improvement=-27.62%
# Trial 032 | order=(3, 0, 2) exog=True allocation=last_year_share | WMAE=3093.7297 | improvement=-71.86%
# Trial 033 | order=(3, 0, 3) exog=True allocation=last_year_share | WMAE=1924.7280 | improvement=-6.92%
# Trial 034 | order=(3, 0, 4) exog=True allocation=last_year_share | WMAE=2045.8723 | improvement=-13.65%
# Trial 035 | order=(3, 1, 0) exog=True allocation=last_year_share | WMAE=3317.8184 | improvement=-84.31%
# Trial 036 | order=(3, 1, 1) exog=True allocation=last_year_share | WMAE=3238.2880 | improvement=-79.89%
# Trial 037 | order=(3, 1, 2) exog=True allocation=last_year_share | WMAE=2995.4492 | improvement=-66.40%
# Trial 038 | order=(3, 1, 3) exog=True allocation=last_year_share | WMAE=1863.6190 | improvement=-3.52%
# Trial 039 | order=(3, 1, 4) exog=True allocation=last_year_share | WMAE=1879.5669 | improvement=-4.41%
# Trial 040 | order=(4, 0, 0) exog=True allocation=last_year_share | WMAE=3763.5419 | improvement=-109.07%
# Trial 041 | order=(4, 0, 1) exog=True allocation=last_year_share | WMAE=3670.6685 | improvement=-103.91%
# Trial 042 | order=(4, 0, 2) exog=True allocation=last_year_share | WMAE=3077.1364 | improvement=-70.94%
# Trial 043 | order=(4, 0, 3) exog=True allocation=last_year_share | WMAE=3137.4893 | improvement=-74.29%
# Trial 044 | order=(4, 0, 4) exog=True allocation=last_year_share | WMAE=1958.4302 | improvement=-8.79%
# Trial 045 | order=(4, 1, 0) exog=True allocation=last_year_share | WMAE=3512.3860 | improvement=-95.11%
# Trial 046 | order=(4, 1, 1) exog=True allocation=last_year_share | WMAE=3275.5380 | improvement=-81.96%
# Trial 047 | order=(4, 1, 2) exog=True allocation=last_year_share | WMAE=3077.0954 | improvement=-70.93%
# Trial 048 | order=(4, 1, 3) exog=True allocation=last_year_share | WMAE=1927.0116 | improvement=-7.05%
# Trial 049 | order=(4, 1, 4) exog=True allocation=last_year_share | WMAE=1919.8670 | improvement=-6.65%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>baseline/seasonal_naive_wmae</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>improvement_vs_seasonal_naive_pct</td><td>▁▁▁▁▁████▇██▇███▇█▇█▇█████▇█▇▇██▇▇▇█▇▇▇█</td></tr><tr><td>trial</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇██</td></tr><tr><td>validation/mae</td><td>█████▁▁▁▁▂▁▁▁▂▁▁▁▂▁▂▁▂▁▁▁▂▁▂▁▁▂▂▁▁▂▁▂▂▂▁</td></tr><tr><td>validation/rmse</td><td>█████▁▁▁▁▂▁▁▂▁▁▁▂▁▂▁▂▁▁▁▁▁▂▁▁▂▂▁▁▂▂▁▂▂▂▁</td></tr><tr><td>validation/wmae</td><td>█████▁▁▁▁▂▁▁▁▁▁▁▂▁▁▁▁▁▁▁▂▂▁▁▂▂▁▁▂▂▂▁▂▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>baseline/seasonal_naive_wmae</td><td>1800.17359</td></tr><tr><td>best_allocation</td><td>last_year_share</td></tr><tr><td>best_order</td><td>(1, 0, 1)</td></tr><tr><td>best_use_exog</td><td>True</td></tr><tr><td>best_validation_mae</td><td>1846.41686</td></tr><tr><td>best_validation_rmse</td><td>3946.39727</td></tr><tr><td>best_validation_wmae</td><td>1824.48155</td></tr><tr><td>improvement_vs_seasonal_naive_pct</td><td>-6.64899</td></tr><tr><td>seasonal_naive_wmae</td><td>1800.17359</td></tr><tr><td>trial</td><td>49</td></tr><tr><td>+3</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">ARIMAX_Repaired_LogTarget_Fourier_Experiment</strong> at: <a href='https://wandb.ai/kende23-n-a/Walmart-Recruiting---Store-Sales-Forecasting/runs/0bgqftvh' target="_blank">https://wandb.ai/kende23-n-a/Walmart-Recruiting---Store-Sales-Forecasting/runs/0bgqftvh</a><br> View project at: <a href='https://wandb.ai/kende23-n-a/Walmart-Recruiting---Store-Sales-Forecasting' target="_blank">https://wandb.ai/kende23-n-a/Walmart-Recruiting---Store-Sales-Forecasting</a><br>Synced 5 W&B file(s), 1 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260717_114510-0bgqftvh/logs</code>
#    trial      order  use_exog       allocation  validation/wmae  \
# 0     11  (1, 0, 1)      True  last_year_share      1824.481552
# 1      6  (0, 1, 1)      True  last_year_share      1830.111348
# 2     17  (1, 1, 2)      True  last_year_share      1832.439459
# 3     12  (1, 0, 2)      True  last_year_share      1835.270724
# 4      7  (0, 1, 2)      True  last_year_share      1854.059601
# 5     38  (3, 1, 3)      True  last_year_share      1863.619031
# 6     28  (2, 1, 3)      True  last_year_share      1864.376950
# 7     29  (2, 1, 4)      True  last_year_share      1867.332082
# 8     19  (1, 1, 4)      True  last_year_share      1868.088477
# 9     26  (2, 1, 1)      True  last_year_share      1870.341365
#
#    validation/mae  validation/rmse  improvement_vs_seasonal_naive_pct
# 0     1846.416858      3946.397271                          -1.350312
# 1     1850.966939      3935.691864                          -1.663048
# 2     1850.694492      3934.294278                          -1.792375
# 3     1845.625915      3937.880515                          -1.949653
# 4     1858.900378      3945.911088                          -2.993378
# 5     1857.507681      3944.722689                          -3.524407
# 6     1857.707520      3944.963478                          -3.566509
# 7     1858.642796      3950.265489                          -3.730667
# 8     1862.973362      3953.645737                          -3.772685
# 9     1869.453051      3960.259639                          -3.897834
# {'trial': 11,
#  'order': (1, 0, 1),
#  'use_exog': True,
#  'allocation': 'last_year_share',
#  'validation/wmae': 1824.481552384862,
#  'validation/mae': 1846.4168582946959,
#  'validation/rmse': 3946.397270568514,
#  'improvement_vs_seasonal_naive_pct': -1.3503120380637448}

# %% [markdown]
# ## Register Best ARIMAX Pipeline
#
# Run this cell after the experiment loop. It refits the best ARIMAX order on all available training data, packages the fitted aggregate model with selected exogenous features and allocation history, logs it as a W&B model artifact, and links it to the W&B Model Registry.

# %%
required_objects = [
    "best_result",
    "train",
    "features",
    "weekly_total_sales",
    "build_weekly_exog",
    "selected_exog_features",
]
missing_objects = [name for name in required_objects if name not in globals()]
if missing_objects:
    raise RuntimeError(
        "Run previous experiment cells first. Missing: " + ", ".join(missing_objects)
    )
if wandb is None:
    raise ImportError(
        "wandb is not available. Re-run the install/import cell or install wandb."
    )

REGISTER_ARIMAX_MODEL = True
ARIMAX_REGISTRY_TARGET = "wandb-registry-model/Walmart_ARIMAX_Pipeline"
ARIMAX_MODEL_ARTIFACT_NAME = "walmart-arimax-best-pipeline"


class AggregateARIMAXPipeline:
    """Raw-test ARIMAX pipeline for W&B Model Registry."""

    def __init__(
        self,
        model_result,
        order,
        allocation_strategy,
        observed_history,
        feature_history,
        selected_features,
        exog_center,
        exog_scale,
        validation_metrics,
        metadata,
    ):
        self.model_result = model_result
        self.order = tuple(order)
        self.allocation_strategy = allocation_strategy
        self.observed_history = observed_history.copy()
        self.feature_history = feature_history.copy()
        self.selected_features = list(selected_features)
        self.exog_center = pd.Series(exog_center).copy()
        self.exog_scale = pd.Series(exog_scale).replace(0.0, 1.0).copy()
        self.validation_metrics = dict(validation_metrics)
        self.metadata = dict(metadata)

    def _build_weekly_exog(self, features_frame):
        frame = features_frame.copy()
        markdown_cols = [c for c in frame.columns if c.startswith("MarkDown")]
        for col in markdown_cols:
            frame[col] = frame[col].fillna(0.0)
        numeric_cols = [
            "Temperature",
            "Fuel_Price",
            "CPI",
            "Unemployment",
        ] + markdown_cols
        for col in numeric_cols:
            if col in frame.columns:
                frame[col] = frame[col].fillna(frame[col].median())
        aggregations = {
            "IsHoliday": "mean",
            "Temperature": "mean",
            "Fuel_Price": "mean",
            "CPI": "mean",
            "Unemployment": "mean",
        }
        for col in markdown_cols:
            aggregations[col] = "sum"
        weekly = frame.groupby("Date").agg(aggregations).sort_index().asfreq("W-FRI")
        weekly = weekly.rename(columns={"IsHoliday": "holiday_share"})
        weekly["total_markdown"] = (
            weekly[markdown_cols].sum(axis=1) if markdown_cols else 0.0
        )
        weekly["weekofyear"] = weekly.index.isocalendar().week.astype(int)
        weekly["week_sin"] = np.sin(2 * np.pi * weekly["weekofyear"] / 52.0)
        weekly["week_cos"] = np.cos(2 * np.pi * weekly["weekofyear"] / 52.0)
        weekly["week_sin_2"] = np.sin(4 * np.pi * weekly["weekofyear"] / 52.0)
        weekly["week_cos_2"] = np.cos(4 * np.pi * weekly["weekofyear"] / 52.0)
        weekly["log_total_markdown"] = np.log1p(weekly["total_markdown"].clip(lower=0.0))
        return weekly.replace([np.inf, -np.inf], np.nan).ffill().bfill().fillna(0.0)

    def _aggregate_forecast(self, raw_df, features_frame=None):
        dates = list(pd.to_datetime(sorted(raw_df["Date"].unique())))
        source_features = (
            self.feature_history if features_frame is None else features_frame.copy()
        )
        source_features["Date"] = pd.to_datetime(source_features["Date"])
        weekly_exog_future = self._build_weekly_exog(source_features).loc[dates, self.selected_features].astype(float)
        weekly_exog_future = (weekly_exog_future - self.exog_center) / self.exog_scale
        forecast = self.model_result.get_forecast(
            steps=len(dates), exog=weekly_exog_future
        ).predicted_mean
        forecast = np.expm1(np.asarray(forecast))
        return pd.Series(forecast, index=dates).clip(lower=0.0)

    def predict(self, raw_df, features_frame=None):
        frame = raw_df.copy()
        frame["Date"] = pd.to_datetime(frame["Date"])
        if "IsHoliday" not in frame.columns:
            frame["IsHoliday"] = False
        aggregate_forecast = self._aggregate_forecast(
            frame, features_frame=features_frame
        )
        return self._make_row_forecast(frame, aggregate_forecast)

    def _make_row_forecast(self, target_frame, aggregate_forecast, recent_weeks=13):
        target = target_frame[["Store", "Dept", "Date", "IsHoliday"]].copy()
        history = self.observed_history[
            ["Store", "Dept", "Date", "Weekly_Sales"]
        ].copy()
        history["Date"] = pd.to_datetime(history["Date"])
        last_year = history.copy()
        last_year["Date"] = last_year["Date"] + pd.Timedelta(days=364)
        last_year = last_year.rename(columns={"Weekly_Sales": "last_year_sales"})
        series_mean = (
            history.groupby(["Store", "Dept"], as_index=False)["Weekly_Sales"]
            .mean()
            .rename(columns={"Weekly_Sales": "series_mean_sales"})
        )
        recent_cutoff = history["Date"].max() - pd.Timedelta(days=7 * recent_weeks)
        recent_mean = (
            history[history["Date"] > recent_cutoff]
            .groupby(["Store", "Dept"], as_index=False)["Weekly_Sales"]
            .mean()
            .rename(columns={"Weekly_Sales": "recent_mean_sales"})
        )
        target = target.merge(last_year, on=["Store", "Dept", "Date"], how="left")
        target = target.merge(series_mean, on=["Store", "Dept"], how="left")
        target = target.merge(recent_mean, on=["Store", "Dept"], how="left")
        if self.allocation_strategy == "last_year_share":
            base = target["last_year_sales"].fillna(target["series_mean_sales"])
        elif self.allocation_strategy == "blended_share":
            last_year_base = target["last_year_sales"].fillna(
                target["series_mean_sales"]
            )
            recent_base = target["recent_mean_sales"].fillna(
                target["series_mean_sales"]
            )
            base = 0.70 * last_year_base + 0.30 * recent_base
        else:
            raise ValueError(f"Unknown allocation strategy: {self.allocation_strategy}")
        target["allocation_base"] = base.fillna(0.0).clip(lower=0.0)
        date_base_sum = target.groupby("Date")["allocation_base"].transform("sum")
        row_count = target.groupby("Date")["allocation_base"].transform("size")
        target["share"] = np.where(
            date_base_sum > 0,
            target["allocation_base"] / date_base_sum,
            1.0 / row_count,
        )
        target["aggregate_forecast"] = target["Date"].map(aggregate_forecast)
        target["prediction"] = (
            (target["aggregate_forecast"] * target["share"]).fillna(0.0).clip(lower=0.0)
        )
        return target["prediction"].to_numpy()


if REGISTER_ARIMAX_MODEL:
    best_order = tuple(best_result["order"])
    best_allocation = best_result["allocation"]
    full_weekly_sales = weekly_total_sales(train)
    full_weekly_exog = build_weekly_exog(features)
    full_exog_raw = full_weekly_exog.loc[full_weekly_sales.index, selected_exog_features].astype(float)
    full_exog_center = full_exog_raw.mean(axis=0)
    full_exog_scale = full_exog_raw.std(axis=0).replace(0.0, 1.0)
    full_exog_train = (full_exog_raw - full_exog_center) / full_exog_scale
    full_model = SARIMAX(
        np.log1p(np.clip(full_weekly_sales.to_numpy(dtype=float), 0.0, None)),
        order=best_order,
        seasonal_order=(0, 0, 0, 0),
        exog=full_exog_train,
        enforce_stationarity=False,
        enforce_invertibility=False,
    ).fit(disp=False, maxiter=300)

    registry_output_dir = OUTPUT_DIR / "arimax_registry"
    registry_output_dir.mkdir(parents=True, exist_ok=True)
    pipeline_path = registry_output_dir / "arimax_best_pipeline.pkl"

    validation_metrics = {
        "best_validation_wmae": float(best_result["validation/wmae"]),
        "best_validation_mae": float(best_result["validation/mae"]),
        "best_validation_rmse": float(best_result["validation/rmse"]),
        "seasonal_naive_wmae": float(seasonal_naive_wmae),
        "improvement_vs_seasonal_naive_pct": float(
            best_result["improvement_vs_seasonal_naive_pct"]
        ),
    }
    pipeline = AggregateARIMAXPipeline(
        model_result=full_model,
        order=best_order,
        allocation_strategy=best_allocation,
        observed_history=train,
        feature_history=features,
        selected_features=selected_exog_features,
        exog_center=full_exog_center,
        exog_scale=full_exog_scale,
        validation_metrics=validation_metrics,
        metadata={
            "model_family": "ARIMAX",
            "uses_exog": True,
            "selected_exog_features": selected_exog_features,
            "seasonal_order": "disabled",
            "target_transform": "log1p",
            "exog_scaling": "full-train mean/std",
            "validation_weeks": VALIDATION_WEEKS,
            "refit_scope": "full_train",
        },
    )
    with pipeline_path.open("wb") as file:
        cloudpickle.dump(pipeline, file)

    registry_run = wandb.init(
        project=WANDB_PROJECT,
        name="ARIMAX_Best_Model_Registry",
        job_type="model_registration",
        mode=WANDB_MODE,
        reinit=True,
        config={
            **validation_metrics,
            "best_order": str(best_order),
            "best_allocation": best_allocation,
            "selected_exog_features": selected_exog_features,
            "registry_target": ARIMAX_REGISTRY_TARGET,
        },
    )
    model_artifact = wandb.Artifact(
        name=ARIMAX_MODEL_ARTIFACT_NAME,
        type="model",
        description="Best aggregate ARIMAX pipeline with selected exogenous features and row-level Store-Dept allocation.",
        metadata={
            **validation_metrics,
            "model_family": "ARIMAX",
            "order": str(best_order),
            "allocation_strategy": best_allocation,
            "selected_exog_features": selected_exog_features,
            "registry_target": ARIMAX_REGISTRY_TARGET,
        },
    )
    model_artifact.add_file(str(pipeline_path))
    logged_artifact = registry_run.log_artifact(
        model_artifact, aliases=["best", "latest"]
    )
    registry_run.link_artifact(
        logged_artifact,
        target_path=ARIMAX_REGISTRY_TARGET,
        aliases=["best-arimax", "latest", "champion"],
    )
    registry_run.summary.update(validation_metrics)
    registry_run.summary["registry_target"] = ARIMAX_REGISTRY_TARGET
    registry_run.summary["pipeline_artifact"] = ARIMAX_MODEL_ARTIFACT_NAME
    registry_run.finish()

    print("Registered best ARIMAX pipeline in W&B Model Registry:")
    print(f"  artifact: {ARIMAX_MODEL_ARTIFACT_NAME}")
    print(f"  registry: {ARIMAX_REGISTRY_TARGET}")
    print(f"  validation WMAE: {validation_metrics['best_validation_wmae']:.4f}")
# Out:
# Tracking run with wandb version 0.28.0
# Run data is saved locally in <code>/content/wandb/run-20260717_115950-gdy1n77f</code>
# Syncing run <strong><a href='https://wandb.ai/kende23-n-a/Walmart-Recruiting---Store-Sales-Forecasting/runs/gdy1n77f' target="_blank">ARIMAX_Best_Model_Registry</a></strong> to <a href='https://wandb.ai/kende23-n-a/Walmart-Recruiting---Store-Sales-Forecasting' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/kende23-n-a/Walmart-Recruiting---Store-Sales-Forecasting' target="_blank">https://wandb.ai/kende23-n-a/Walmart-Recruiting---Store-Sales-Forecasting</a>
#  View run at <a href='https://wandb.ai/kende23-n-a/Walmart-Recruiting---Store-Sales-Forecasting/runs/gdy1n77f' target="_blank">https://wandb.ai/kende23-n-a/Walmart-Recruiting---Store-Sales-Forecasting/runs/gdy1n77f</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_validation_mae</td><td>1846.41686</td></tr><tr><td>best_validation_rmse</td><td>3946.39727</td></tr><tr><td>best_validation_wmae</td><td>1824.48155</td></tr><tr><td>improvement_vs_seasonal_naive_pct</td><td>-1.35031</td></tr><tr><td>pipeline_artifact</td><td>walmart-arimax-best-...</td></tr><tr><td>registry_target</td><td>wandb-registry-model...</td></tr><tr><td>seasonal_naive_wmae</td><td>1800.17359</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">ARIMAX_Best_Model_Registry</strong> at: <a href='https://wandb.ai/kende23-n-a/Walmart-Recruiting---Store-Sales-Forecasting/runs/gdy1n77f' target="_blank">https://wandb.ai/kende23-n-a/Walmart-Recruiting---Store-Sales-Forecasting/runs/gdy1n77f</a><br> View project at: <a href='https://wandb.ai/kende23-n-a/Walmart-Recruiting---Store-Sales-Forecasting' target="_blank">https://wandb.ai/kende23-n-a/Walmart-Recruiting---Store-Sales-Forecasting</a><br>Synced 4 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260717_115950-gdy1n77f/logs</code>
# Registered best ARIMAX pipeline in W&B Model Registry:
#   artifact: walmart-arimax-best-pipeline
#   registry: wandb-registry-model/Walmart_ARIMAX_Pipeline
#   validation WMAE: 1824.4816

# %% [markdown]
# ## Optional Best ARIMAX Submission
#
# Set `RUN_TEST_SUBMISSION=True` only after reviewing validation results. This refits the best aggregate ARIMAX setup on all training dates and creates a Kaggle CSV.

# %%
RUN_TEST_SUBMISSION=True
if RUN_TEST_SUBMISSION:
    best_order = tuple(best_result["order"])
    best_use_exog = bool(best_result["use_exog"])
    best_allocation = best_result["allocation"]

    full_weekly_sales = weekly_total_sales(train)
    test_dates = list(pd.to_datetime(sorted(test["Date"].unique())))
    exog_train_raw = weekly_exog.loc[full_weekly_sales.index, selected_exog_features].astype(float)
    exog_test_raw = weekly_exog.loc[test_dates, selected_exog_features].astype(float)
    submission_center = exog_train_raw.mean(axis=0)
    submission_scale = exog_train_raw.std(axis=0).replace(0.0, 1.0)
    exog_train_full = (exog_train_raw - submission_center) / submission_scale
    exog_test = (exog_test_raw - submission_center) / submission_scale

    _, aggregate_test_forecast = fit_forecast_arima(
        full_weekly_sales, test_dates, best_order, exog_train_full, exog_test
    )
    test_pred = make_row_forecast(test, train, aggregate_test_forecast, best_allocation)

    submission = pd.DataFrame(
        {
            "Id": test["Store"].astype(str)
            + "_"
            + test["Dept"].astype(str)
            + "_"
            + test["Date"].dt.strftime("%Y-%m-%d"),
            "Weekly_Sales": test_pred,
        }
    )
    submission_path = OUTPUT_DIR / "arimax_experiment_submission.csv"
    submission.to_csv(submission_path, index=False)
    print(f"Saved {submission_path} with {len(submission)} rows")
    display(submission.head())
else:
    print(
        "Submission skipped. Set RUN_TEST_SUBMISSION=True after reviewing validation results."
    )
# Out:
# Saved outputs/arimax_experiment_submission.csv with 115064 rows
#                Id  Weekly_Sales
# 0  1_1_2012-11-02  39434.663164
# 1  1_2_2012-11-02  46778.164295
# 2  1_3_2012-11-02   9085.204373
# 3  1_4_2012-11-02  38909.455065
# 4  1_5_2012-11-02  31594.418112
