# %%
import kagglehub

# Download latest version
path = kagglehub.competition_download("walmart-recruiting-store-sales-forecasting")

print("Path to competition files:", path)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import kagglehub
#       3 # Download latest version
#       4 path = kagglehub.competition_download('walmart-recruiting-store-sales-forecasting')
#
# ModuleNotFoundError: No module named 'kagglehub'

# %%
import sys

print(sys.executable)
# Out:
# /home/konstantine/Documents/work/ml/.venv/bin/python
